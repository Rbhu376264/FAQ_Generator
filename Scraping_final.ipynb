# %%
import csv
import requests
from bs4 import BeautifulSoup
import json

csv_file_path = 'University List - Sheet1.csv'
output_json_path = 'output.json'
universities_info = {}

with open(csv_file_path, mode='r', encoding='utf-8') as csv_file:
    csv_reader = csv.reader(csv_file)
    next(csv_reader)
    for row in csv_reader:

        if not all(row[:3]):  # This checks if any of the first three columns are empty
            continue  # Skip this iteration if any required information is missing

        univ_name, admission_url, faq_url = row[:3]
        universities_info[univ_name] = {"FAQs": [], "AdmissionText": ""}
        try:
          faq_response = requests.get(faq_url, headers={
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}, verify=False)
          if faq_response.status_code == 200:
                soup = BeautifulSoup(faq_response.text, 'html.parser')
                texts = soup.find_all(text=True)
                faqs = [text.strip() for text in texts if text.strip().endswith('?')][:10]  # Get only the first 10 FAQs
                universities_info[univ_name]["FAQs"] = faqs
        except Exception as e:
            print(f"Error fetching FAQ for {univ_name}: {e}")

        try:
          admission_response = requests.get(admission_url, headers={'User-Agent': 'Mozilla/5.0'}, verify=False)
          if admission_response.status_code == 200:
              soup = BeautifulSoup(admission_response.text, 'html.parser')
              # Extract all paragraph texts or any other criteria you define for the admission text
              admission_texts = soup.find_all('p')
              admission_paragraphs = [text.get_text(strip=True) for text in admission_texts if text.get_text(strip=True)]
              universities_info[univ_name]["AdmissionText"] = admission_paragraphs
        except Exception as e:
            print(f"Error fetching admission info for {univ_name}: {e}")





# Write the data to a JSON file
with open(output_json_path, 'w', encoding='utf-8') as json_file:
    json.dump(universities_info, json_file, ensure_ascii=False, indent=4)
# Out:
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.cs.stanford.edu'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# <ipython-input-1-8d7f3bdc2e0d>:25: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   texts = soup.find_all(text=True)
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.cs.stanford.edu'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# ...

# %%
import json

# Path to the JSON file
json_file_path = 'output.json'

# Read the JSON file
with open(json_file_path, 'r', encoding='utf-8') as file:
    universities_info = json.load(file)

for univ_name, info in universities_info.items():
    print(f"University Name: {univ_name}")
    print("FAQs:")
    for faq in info["FAQs"]:
        print(f"  - {faq}")
    print("Admission Text:")
    for paragraph in info["AdmissionText"]:
        print(paragraph)
    print("\n")  # Add extra newline for better readability
    break
# Out:
# University Name: Stanford University
# FAQs:
#   - Looking for your W-2 form?
#   - Do you have to be a Computer Science undergraduate major to apply?
#   - If I already have an MS or PhD degree in Computer Science from another institution, may I apply to the MS or PhD program at Stanford?
#   - Are my units transferable?
#   - Do you accept visiting scholars, exchange students, and postdocs?
#   - Where can I find housing information?
#   - What is HCP and how do I apply to that program?
#   - If I am accepted into the HCP program, can I go full-time once I enroll?
#   - What is NDO and how do I apply to that program?
#   - If I take NDO classes, does that mean I will automatically get into the CS Master's program if I apply?
# Admission Text:
# Email forwarding for @cs.stanford.edu is changing. Updates and detailshere.Looking for your W-2 form?Read Here.CS Commencement Ceremony June 16, 2024.Learn More.
# ...

# %%
import csv
import json

# Path to the JSON file
json_file_path = 'output.json'
# Path to the new CSV file
csv_file_path = 'data.csv'

# Read the JSON file
with open(json_file_path, 'r', encoding='utf-8') as file:
    universities_info = json.load(file)

# Create and write to the CSV file
with open(csv_file_path, mode='w', encoding='utf-8', newline='') as file:
    csv_writer = csv.writer(file)
    # Write the header row
    csv_writer.writerow(['University Name', 'Admission Text', 'FAQs'])

    for univ_name, info in universities_info.items():
        # Combine FAQs into a single string separated by a specific character (e.g., " | ")
        faqs_combined = " | ".join(info["FAQs"])
        # Combine AdmissionText paragraphs into a single string. If AdmissionText is already a string, you can skip this step.
        admission_text_combined = " ".join(info["AdmissionText"]) if isinstance(info["AdmissionText"], list) else info["AdmissionText"]
        # Write the university's admission text and FAQs to a new row in the CSV file
        csv_writer.writerow([univ_name, admission_text_combined, faqs_combined])
